# %%
def isPhoneNumber(phone_number):
    if len(phone_number) !=12: 
        return False
    for phn in range(0, 3):
        if not phone_number[phn].isdecimal():
            return False
    if phone_number[3] != '-':
        return False
    for phn in range(4, 7):
        if not phone_number[phn].isdecimal():
            return False
    if phone_number[7] != '-':
        return False
    for phn in range(8, 12):
        if not phone_number[phn].isdecimal():
            return False
    return True

# %%
print("415-555-4242 is a phone number: ")
print(isPhoneNumber('415-555-4242'))
print('Moshi moshi is a phone number: ')
print(isPhoneNumber('Moshi moshi'))
# Out:
# 415-555-4242 is a phone number:
# True
# Moshi moshi is a phone number:
# False

# %%
message = 'Call me at 415-555-1011 tomorrow. 415-555-9999 is my office.'
for char in range(len(message)):
    chunk = message[char:char+12]
    if isPhoneNumber(chunk):
        print('Phone number found: ' + chunk)
print ('Done')
# Out:
# Phone number found: 415-555-1011
# Phone number found: 415-555-9999
# Done

# %% [markdown]
# # List, Sets and Truples

# %%
# zip “pairs” up the elements of a number of lists, tuples, or other sequences to create a list of tuples
seq1 = ["foo", "bar", "baz"]
seq2 = ["one", "two", "three"]
zipped = zip(seq1, seq2)
list(zipped)
# Out:
# [('foo', 'one'), ('bar', 'two'), ('baz', 'three')]

# %%
'''zip can take an arbitrary
        number of sequences, and the number of elements it produces is
        determined by the shortest sequence: '''
seq3 = [False, True]
list(zip(seq1, seq2, seq3))
# Out:
# [('foo', 'one', False), ('bar', 'two', True)]

# %%
for index, (a, b) in enumerate(zip(seq1, seq2)):
    print(f"{index}: {a}, {b}")
# Out:
# 0: foo, one
# 1: bar, two
# 2: baz, three

# %%
# enumerate
import string
rand_list = list(range(0,25))
aphb_list = list(string.ascii_lowercase)

# %%
zipped_list = list(zip(aphb_list, rand_list))

for index, (ltr, num) in enumerate(zipped_list):
    print(f"{ltr} is {num} in code")
# Out:
# a is 0 in code
# b is 1 in code
# c is 2 in code
# d is 3 in code
# e is 4 in code
# f is 5 in code
# g is 6 in code
# h is 7 in code
# i is 8 in code
# j is 9 in code
# k is 10 in code
# l is 11 in code
# m is 12 in code
# n is 13 in code
# o is 14 in code
# p is 15 in code
# q is 16 in code
# r is 17 in code
# s is 18 in code
# t is 19 in code
# u is 20 in code
# v is 21 in code
# w is 22 in code
# x is 23 in code
# y is 24 in code

# %%
zipped_list
# Out:
# [('abcdefghijklmnopqrstuvwxyz', range(0, 25))]

# %%
from operator import itemgetter

student = [
    ("A", 90),
    ("B", 80)
]

print(itemgetter(1)(student[0]))
# Out:
# 90

# %%
print(student[0][1])
# Out:
# 90

# %% [markdown]
# # Returning Multiple Values

# %%
def f(): 
    a = 5
    b = 6
    c = 7
    return a, b, c

# %%
a, b, c = f()

# %%
print(a, b, c)
# Out:
# 5 6 7

# %%
# Alternative technique is returning a dictionary 
def f(): 
    a = 5
    b = 6
    c = 7
    return {"a":a, "b":b, "c": c}
