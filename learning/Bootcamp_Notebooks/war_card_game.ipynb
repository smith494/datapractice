# %%
#CARD Class
#imports
import random
# Global Variables 
suits = ("Spades", "Hearts", "Diamonds", "Clubs")
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 
            'Nine':9, 'Ten':10, 'Jack':11, 'Queen':12, 'King':13, 'Ace':14}

# %%
class Card:

    def __init__(self, suit, rank): 
        self.suit = suit
        self.rank = rank
        self.value = values[rank]
    
    def __str__(self):
        return self.rank + " of " + self.suit

# %%
two_hearts = Card(suits[1], ranks[0])
three_clubs = Card('Clubs', 'Three')

# %%
print(two_hearts)
# Out:
# Two of Hearts

# %%
two_hearts.value < three_clubs.value
# Out:
# True

# %%
class Deck:

    def __init__(self): 
        self.full_deck = []

        for suit in suits: 
            for rank in ranks:
                self.full_deck.append(Card(suit, rank))
    
    def shuffle_deck(self): 
        random.shuffle(self.full_deck)
    
    def deal_one(self): 
        return self.full_deck.pop()

# %%
first_deck = Deck()

# %%
mycard =first_deck.deal_one()

# %%
len(first_deck.full_deck)
# Out:
# 51

# %%
class Player:

    def __init__(self, name): 
        self.name = name
        self.player_hand = []
    
    def play_one(self): 
        return self.player_hand.pop(0)

    def add_cards(self, new_card):
        if (type(new_card ) == type([])):
            return self.player_hand.extend(new_card)
        else: 
            self.player_hand.append(new_card)

    def __str__(self): 
        return f'Player {self.name} has {len(self.player_hand)} cards'

# %%
player_one = Player("Courtney")

# %%
print(player_one)
# Out:
# Player Courtney has 0 cards

# %%
player_one.add_cards(mycard)

# %%
print(player_one)
# Out:
# Player Courtney has 1 cards

# %%
player_one.add_cards([mycard, mycard, mycard])

# %%
print(player_one)
# Out:
# Player Courtney has 3 cards

# %%
print(player_one.play_one())
# Out:
# Ace of Clubs

# %%
# Game Setup 
player_one = Player('One')
player_two = Player('Two')

new_deck = Deck()
new_deck.shuffle_deck()

for card_count in range(26):
    player_one.add_cards(new_deck.deal_one())
    player_two.add_cards(new_deck.deal_one())

# %%
game_on = True

# %%
# Game Playing While Loop 
game_round = 0
while game_on: 

    game_round += 1

    print(f'Round {game_round}')

    if len(player_one.player_hand) == 0: 
        print('Player One has no cards left. Player Two has won!')
        game_on = False
        break

    if len(player_two.player_hand) == 0: 
        print('Player Two has no cards left. Player One has won!')
        game_on = False
        break

    # Start New Round
    player_one_cards = []
    player_one_cards.append(player_one.play_one())
    
    player_two_cards = []
    player_two_cards.append(player_two.play_one())


    # While at_war loop 
    at_war = True
    while at_war:

        if player_one_cards[-1].value > player_two_cards[-1].value: 

            player_one.add_cards(player_one_cards)
            player_one.add_cards(player_two_cards)

            at_war = False

        elif player_one_cards[-1].value < player_two_cards[-1].value: 

            player_two.add_cards(player_one_cards)
            player_two.add_cards(player_two_cards)
            
            at_war = False
        
        else: 
            print("WAR!")

            if len(player_one.player_hand) < 5: 
                print("Player One is Unable to Declare War")
                print("Player Two Wins")

                game_on = False
                break

            elif len(player_two.player_hand) < 5: 
                print("Player Two is Unable to Declare War")
                print("Player One Wins")

                game_on = False
                break
            else: 
                for num in range(5):
                    player_one_cards.append(player_one.play_one())
                    player_two_cards.append(player_two.play_one())
# Out:
# Round 1
# Round 2
# Round 3
# WAR!
# Round 4
# Round 5
# Round 6
# Round 7
# Round 8
# Round 9
# Round 10
# Round 11
# Round 12
# Round 13
# Round 14
# Round 15
# Round 16
# Round 17
# Round 18
# Round 19
# Round 20
# Round 21
# Round 22
# Round 23
# Round 24
# Round 25
# Round 26
# Round 27
# Round 28
# Round 29
# Round 30
# Round 31
# Round 32
# Round 33
# Round 34
# Round 35
# Round 36
# Round 37
# Round 38
# Round 39
# Round 40
# Round 41
# WAR!
# Round 42
# Round 43
# Round 44
# Round 45
# Round 46
# Round 47
# Round 48
# Round 49
# Round 50
# Round 51
# Round 52
# Round 53
# Round 54
# Round 55
# Round 56
# Round 57
# Round 58
# Round 59
# Round 60
# Round 61
# WAR!
# Round 62
# Round 63
# Round 64
# Round 65
# Round 66
# Round 67
# Round 68
# Round 69
# Round 70
# Round 71
# Round 72
# Round 73
# Round 74
# WAR!
# Player One is Unable to Declare War
# Player Two Wins
