# %%
game_list = [0, 1, 2]

# %%
def display_game_board(game_list):
    choice = True
    selection_list = ['0', '1', '2']

    while choice not in selection_list :
        choice = input("Please enter (0, 1, 2)")
        print(game_list)

        if choice not in selection_list: 
            print("please enter one of the following number (0, 1, 2)")
           
        else: 
            return int(choice)

# %%
display_game_board(game_list)
# Out:
# [0, 1, 2]
# please enter one of the following number (0, 1, 2)
# [0, 1, 2]
# 2

# %%
def position_choice():

    choice = 'wrong'
    acceptable_list = [0, 1, 2]

    while choice not in acceptable_list:

        choice = input("Pick a position (0, 1, 2): ")

        if choice not in acceptable_list: 
            print("Sorry, invalid choice! ")
            
    return int(choice)

# %%
def replacement_choice (game_list, position):
    user_placement = input("Type a string to place at position: ")

    game_list[position] = user_placement

    return game_list

# %%
def gameon_choice(): 

    choice = 'wrong'

    while choice not in ['Y', 'N']: 

        choice = input("Keep playing? (Y or N) ")

        if choice not in ['Y', 'N']:
            print("Sorry, I don't understand, please choose Y or N ")
    
    if choice == "Y": 
        return True
    else: 
        return False

# %%
game_on = True
game_list = [0, 1, 2]

while game_on:

    display_game_board(game_list)

    position = position_choice()

    game_list = replacement_choice(game_list, position)

    display_game_board(game_list)

    game_on = gameon_choice()
# Out:
# [0, 1, 2]
# please enter one of the following number (0, 1, 2)
# [0, 1, 2]
# please enter one of the following number (0, 1, 2)
# [0, 1, 2]
# Sorry, invalid choice!
# Sorry, invalid choice!
# Sorry, invalid choice!
# Sorry, invalid choice!
# Sorry, invalid choice!
# Sorry, invalid choice!
# Sorry, invalid choice!
# Sorry, invalid choice!
# Sorry, invalid choice!
# Sorry, invalid choice!
# Sorry, invalid choice!
# Sorry, invalid choice!
# Sorry, invalid choice!
# Sorry, invalid choice!
# Sorry, invalid choice!
# Sorry, invalid choice!
# Sorry, invalid choice!
# Sorry, invalid choice!
# Sorry, invalid choice!
# Sorry, invalid choice!
# Sorry, invalid choice!
# Sorry, invalid choice!
