# %% [markdown]
# # Fake Data Generation with Faker
#
# This notebook is set up to generate mock data using the `Faker` library. We also import `pandas` to easily manipulate and export the generated data.

# %%
from faker import Faker
import pandas as pd
import numpy as np 
from datetime import datetime, timedelta
import random


# Initialize Faker
fake = Faker('en_US')
Faker.seed(42)
random.seed(42)
np.random.seed(42)

# %% [markdown]
# ## Generate Data
# Let's generate a list of fake users with names, email addresses, and jobs.

# %%
num_records = 100
data = []

for _ in range(num_records):
    data.append({
        'Name': fake.name(),
        'Email': fake.email(),
        'Job': fake.job(),
        'Address': fake.address(),
        'Company': fake.company()
    })

df = pd.DataFrame(data)
df.head()
# Out:
#              Name                      Email                              Job  \
# 0    Allison Hill   donaldgarcia@example.net             Sports administrator
# 1    Ashley James      melanie94@example.org                Psychiatric nurse
# 2     Maria Lynch  amandasanchez@example.com         Museum education officer
# 3    Maria Thomas    johnhoffman@example.com   Television/film/video producer
# 4  Kimberly Adams       daniel62@example.com  Accountant, chartered certified
#
#                                              Address  \
# 0  01338 Anna Stravenue Suite 379\nLisatown, WV 2...
# 1  84959 Janet Cape Apt. 413\nSouth Joshuastad, G...
# 2               503 Linda Locks\nCarlshire, FM 94599
# 3  3287 Katelyn Wall Apt. 226\nSouth Patrickmouth...
# 4                         USNV Stanton\nFPO AE 67043
#
#                         Company
# 0  Henderson, Ramirez and Lewis
# 1                   Clark-Adams
# 2                  Lewis-Porter
# 3        Valencia, Smith and Le
# 4                   Harrell LLC

# %% [markdown]
# ## Export Data
# Save the generated data to a CSV file.

# %%
df.to_csv('../data/raw/fake_data.csv', index=False)
print("Data successfully saved to ../data/raw/fake_data.csv")
# Out:
# Data successfully saved to fake_data.csv
